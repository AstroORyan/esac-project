# %%
import pandas as pd

# %%
full_manifest = pd.read_csv('C:/Users/oryan/Documents/zoobot/hubble-dataset-creation/data/gz_hubble_main.csv')

# %%
reduced_manifest = full_manifest[['zooniverse_id','total_weight','RA','DEC','t08_odd_feature_a06_merger_weighted_fraction']].rename(columns={'t0_odd_feature_a06_merger_weighted_fraction':'merger_vote'})

# %%
reduced_manifest
# Out:
#        zooniverse_id  total_weight          RA        DEC  \
# 0         AGZ0007xmh        40.000  188.897318  62.200334
# 1         AGZ0007xmi        41.000  188.901464  62.200705
# 2         AGZ0007xmj        40.000  188.901567  62.201482
# 3         AGZ0007xmk        40.000  188.905098  62.199973
# 4         AGZ0007xml        41.000  188.906262  62.198074
# ...              ...           ...         ...        ...
# 113700    AHZ40008nu       169.045   52.873002 -27.580397
# 113701    AHZ40008nv        86.000   53.252911 -27.645872
# 113702    AHZ40008nw       141.560   52.982787 -27.578840
# 113703    AHZ40008nx        30.001   53.189682 -27.948248
# 113704    AHZ40008ny        17.101   53.190271 -27.948498
#
#         t08_odd_feature_a06_merger_weighted_fraction
# 0                                           0.571429
# 1                                           0.166667
# 2                                           0.250000
# 3                                           0.000000
# ...

# %%
vote_red_man = reduced_manifest.query('total_weight >= 100')

# %%
vote_red_man
# Out:
#        zooniverse_id  total_weight          RA        DEC  \
# 11157     AHZ1000001       405.573  214.235824  52.396332
# 11158     AHZ1000002       419.270  214.328535  52.407050
# 11159     AHZ1000003       714.034  214.130396  52.452309
# 11160     AHZ1000004       484.617  214.225495  52.408517
# 11161     AHZ1000005       510.336  214.257599  52.450259
# ...              ...           ...         ...        ...
# 113697    AHZ40008nr       104.162   53.256315 -27.761788
# 113698    AHZ40008ns       122.326   53.370697 -27.665970
# 113699    AHZ40008nt       242.923   53.208246 -27.577137
# 113700    AHZ40008nu       169.045   52.873002 -27.580397
# 113702    AHZ40008nw       141.560   52.982787 -27.578840
#
#         t08_odd_feature_a06_merger_weighted_fraction
# 11157                                          0.091
# 11158                                          0.125
# 11159                                          0.000
# 11160                                          0.321
# ...
